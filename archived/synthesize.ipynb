# %%
from preprocessing import *
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import pathlib as p
DATA_DIR = p.Path.home()/"data"/"bobsrepository"
LR2_DIR = DATA_DIR/"LR"
LR4_DIR = DATA_DIR/"LR4"
t2_files = sorted(DATA_DIR.rglob("*T2w.nii.gz"))
t1_files = sorted(DATA_DIR.rglob("*T1w.nii.gz"))
t2_lr_files = sorted(LR2_DIR.rglob("*T2w_LR.nii.gz"))
t2_lr4_files = sorted(LR4_DIR.rglob("*T2w_LR4.nii.gz"))
# Out:
# /Users/al1612le/mri-sr-bob/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
coregistered_dir = DATA_DIR/"coregistered"/"T2GT"
t2_coregistered_files = sorted(coregistered_dir.rglob("*T2w.nii.gz"))
print(nib.load(t2_coregistered_files[8]).header)
print(nib.load(t2_files[10]).header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  3 182 218 182   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.  1.  1.  1.  0.  0.  0.  0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2501.4 2025-04-22T09:56:22+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : mni
# sform_code      : mni
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# qoffset_x       : 90.0
# qoffset_y       : -126.0
# qoffset_z       : -72.0
# srow_x          : [-1.  0.  0. 90.]
# srow_y          : [   0.    1.    0. -126.]
# srow_z          : [  0.   0.   1. -72.]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  3 182 218 182   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.  1.  1.  1.  0.  0.  0.  0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'5.0.10')
# aux_file        : np.bytes_(b'')
# qform_code      : mni
# sform_code      : mni
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# qoffset_x       : 90.0
# qoffset_y       : -126.0
# qoffset_z       : -72.0
# srow_x          : [-1.  0.  0. 90.]
# srow_y          : [   0.    1.    0. -126.]
# srow_z          : [  0.   0.   1. -72.]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')

# %%
#Apply flirt:

for i in range(len(t2_files)):
    apply_FLIRT(t2_lr4_files[i], t1_files[0], DATA_DIR/"coregistered"/"T2LR4"/t2_lr4_files[i].name)
# Out:
# Python(49913) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49916) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49922) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49925) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49936) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49939) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49944) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49947) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49949) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49952) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49954) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49957) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49968) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49971) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49974) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49977) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49978) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49981) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49987) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49990) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49992) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(49995) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50008) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50011) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50012) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50015) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50017) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50020) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50023) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50026) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50037) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50040) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50041) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50044) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50047) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50050) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50057) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50060) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50077) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50080) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50081) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50084) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50176) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50179) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50183) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50186) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50201) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50204) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50215) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50218) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50219) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50222) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50223) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50226) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50233) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50236) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50247) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50250) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50252) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50255) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50260) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50263) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50271) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50274) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50286) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50289) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50291) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50294) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50295) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50298) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50305) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50308) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50328) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50331) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50345) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50348) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50351) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50354) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50359) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50362) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50370) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50373) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50385) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50388) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50389) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50392) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50395) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50398) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50415) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50418) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50429) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50432) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50433) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50436) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50438) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50441) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50444) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50447) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50449) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50452) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50467) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50470) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50472) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50475) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50482) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50485) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50488) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50491) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50504) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50507) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50508) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50511) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50514) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50517) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50519) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50522) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50533) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50536) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50537) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50540) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50543) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50546) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50558) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50561) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50570) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50573) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50585) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50588) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50589) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50592) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50596) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50599) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50602) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50605) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50616) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50619) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50621) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50624) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50649) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50652) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50656) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50659) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 4
#       1 #Apply flirt:
#       3 for i in range(len(t2_files)):
# ----> 4     apply_FLIRT(t2_lr4_files[i], t1_files[0], DATA_DIR/"coregistered"/"T2LR4"/t2_lr4_files[i].name)
#
# IndexError: list index out of range

# %%
#AUGMENTING
DIR = DATA_DIR/"LR_data"/"sagittal"/"even"/"LR8"
for f in t2_files:
    lr = create_LR_img(nib.load(f).get_fdata(), 8, start_slice=0, direction='sagittal')
    lr_nib = nib.Nifti1Image(lr, nib.load(f).affine)
    nib.save(lr_nib, DIR/f.name.replace("T2w","T2w_LR8"))

# %%
dir = DATA_DIR/"LR_data"/"even"/"LR5"
test = sorted(dir.rglob("*T2w_LR5.nii.gz"))
test = nib.load(test[0])
test.orthoview()
test = normalize(test)
nib.save(test, DATA_DIR/"LR_data"/"even"/"normalized_T2w_LR5.nii.gz")

# %%
#Augmenting with simple LR3
mni = nib.load("/Users/al1612le/nihpd_obj2_asym_nifti/nihpd_asym_17-21_t2w.nii")

transf = "/Users/al1612le/nihpd_obj2_asym_nifti/nihpd_asym_44-60_tal.xfm"
#apply xfm transormation to mni

# %%
lr = create_LR_img(nib.load(t2_files[0]).get_fdata(), 2, start_slice=1)
nib.save(nib.Nifti1Image(lr, affine=nib.load(t2_files[0]).affine), "/Users/al1612le/images/gridmodetrue1.nii.gz")

# %%
#normalize t1 image

# %%
t2_lr_list = []
for t2_file in t2_files:
    t2_lr = create_LR_nifti(nib.load(t2_file), 2)
    #save nifti but with new name ending with T2w_LR.nii.gz in folder LR2
    save_path = os.path.join(SAVE_DIR, t2_file.name.replace("T2w.nii.gz", "T2w_LR.nii.gz"))
    nib.save(t2_lr, save_path)
    

print(t2_lr.header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  3 182 218  91   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.  1.  1.  2.  1.  1.  1.  1.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'5.0.10')
# aux_file        : np.bytes_(b'')
# qform_code      : mni
# sform_code      : mni
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# qoffset_x       : 90.0
# qoffset_y       : -126.0
# qoffset_z       : -72.0
# srow_x          : [-1.  0.  0. 90.]
# srow_y          : [   0.    1.    0. -126.]
# srow_z          : [  0.   0.   1. -72.]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')

# %%
test_nifti = nib.load("/Users/al1612le/zenodo_upload_v2/s0001/t2.nii.gz")
#print(test_nifti.header)

ref_img = nib.load(t1_files[0])
test_nifti = scale_to_reference_img(test_nifti, ref_img)
#print(test_nifti.header)
test_nifti.orthoview()

test_nifti = pad_to_shape(test_nifti, (192,224,192))
print(test_nifti.header)
test_nifti_patches = extract_3D_patches(test_nifti.get_fdata(), (64,64,64), stride=(32,32,32))
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'')
# dim_info        : 0
# dim             : [  3 192 224 192   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float64
# bitpix          : 64
# slice_start     : 0
# pixdim          : [-1.  1.  1.  1.  1.  1.  1.  1.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 0
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'')
# aux_file        : np.bytes_(b'')
# qform_code      : unknown
# sform_code      : aligned
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# qoffset_x       : 95.0
# qoffset_y       : -129.0
# qoffset_z       : -77.0
# srow_x          : [-1.  0.  0. 95.]
# srow_y          : [   0.    1.    0. -129.]
# srow_z          : [  0.   0.   1. -77.]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
